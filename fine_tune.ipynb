# %%
pip install -r requirements.txt
# Out:
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\onkar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# download dataset from roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="SNPu2rud44jyUF9ERSLe")
project = rf.workspace("p2m5").project("car-truck-detection-qh4lk")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car&truck-detection-1 in yolov8:: 100%|██████████| 8652/8652 [00:23<00:00, 363.02it/s]

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load a pretrained model (nano model)
results = model.train(
        data="car&truck-detection-1/data.yaml",
        epochs=30,
        imgsz=640,
        batch=16,          # batch for CPU
        device=0,          # use GPU 0 for training; use device='cpu' for CPU training
        freeze=5,
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = YOLO("yolov8n.pt")  # load a pretrained model (nano model)
#       2 results = model.train(
#       3         data="car&truck-detection-1/data.yaml",
#       4         epochs=30,
#    (...)
#       8         freeze=5,
#       9     )
#
# NameError: name 'YOLO' is not defined

# %%
import cv2
from ultralytics import YOLO

# %%
MODEL_PATH = "C:\\Users\\onkar\\Downloads\\best.pt"  # Path to your fine-tuned model
VIDEO_PATH = "videos/vecteezy_car-and-truck-traffic-on-the-highway-in-europe-poland_7957364.mp4"
OUTPUT_PATH = "output/inference_result.mp4"  # Path to save the output video

# -------------------------------
# Load Model
# -------------------------------
model = YOLO(MODEL_PATH)

# Print class names
for class_id, class_name in model.names.items():
    print(f"Class ID: {class_id}, Class Name: {class_name}")
# Out:
# Class ID: 0, Class Name: car
# Class ID: 1, Class Name: truck
